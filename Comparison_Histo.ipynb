# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ng_snr_ptaspace=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_pta_space_mar_snr_dmgp_set.npy")
epta_snr_ptaspace=np.load("/Users/kalistaw/Desktop/OS_2023_data/epta_pta_space_mar_snr_dmgp_set.npy")
ppta_snr_ptaspace=np.load("/Users/kalistaw/Desktop/OS_2023_data/ppta_pta_space_mar_snr_dmgp_set.npy")

# %%
ng_epta_ppta_snr_orfzero=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_var_gamma_dmgp_set.npy")
ng_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_snr_tspan_ppta_unq_idx_dmgp_set.npy")
epta_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/epta_snr_vg_tspan_ppta_unq_idx.npy")
ppta_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/ppta_snr_vg_tspan_ppta_fx_gamma_dmgp_set.npy")

# %%
plt.hist(ng_epta_ppta_snr_orfzero, histtype='step', lw=2, label='Combined 3 PTAs', color='k',
         bins=20, density=True)
plt.hist(ng_mar_snr, histtype='step', lw=2, label='NANOGrav 3P+ NMOS', color='C2',
         bins=20, density=True)
plt.hist(epta_mar_snr, histtype='step', lw=2, label='EPTA 3P+ NMOS', color='C3',
         bins=20, density=True)
plt.hist(ppta_mar_snr, histtype='step', lw=2, label='PPTA 3P+ NMOS', color='C0',
         bins=20, density=True)

plt.hist(ng_snr_ptaspace, histtype='step', ls='--', label='NANOGrav NMOS', color='C2',
         bins=20, density=True)
plt.hist(epta_snr_ptaspace, histtype='step', ls='--', label='EPTA NMOS', color='C3',
         bins=20, density=True)
plt.hist(ppta_snr_ptaspace, histtype='step', ls='--', label='PPTA NMOS', color='C0',
         bins=20, density=True)

plt.gca().axvline(x=np.mean(ng_epta_ppta_snr_orfzero), lw=2, color='k')
plt.gca().axvline(x=np.mean(ng_mar_snr), lw=1, color='C2')
plt.gca().axvline(x=np.mean(epta_mar_snr), lw=1, color='C3')
plt.gca().axvline(x=np.mean(ppta_mar_snr), lw=1, color='C0')

plt.gca().axvline(x=np.mean(ng_snr_ptaspace), ls='--', color='C2')
plt.gca().axvline(x=np.mean(epta_snr_ptaspace), ls='--', color='C3')
plt.gca().axvline(x=np.mean(ppta_snr_ptaspace), ls='--', color='C0')

plt.legend(loc="upper right")
plt.title("NMOS with Full Timespan Frequencies Across PTAs")
plt.xlabel("S/N")
plt.ylabel("PDF")
plt.savefig("/Users/kalistaw/Desktop/OS_Plots/fx_gamma_snr_set_dmgp.pdf")

# %%
np.mean(ng_epta_ppta_snr_orfzero)
# Out:
# 6.882093377651386

# %%
np.mean(ng_mar_snr)
# Out:
# 5.60312749953194

# %%
np.mean(ng_snr_ptaspace)
# Out:
# 5.520891812651649

# %%
np.mean(ppta_mar_snr)
# Out:
# 0.8096074133773706

# %%
np.mean(ppta_snr_ptaspace)
# Out:
# 0.0013529384008760675

# %%
np.mean(epta_mar_snr)
# Out:
# 3.431318342622771

# %%
np.mean(epta_snr_ptaspace)
# Out:
# 1.9959105103860433

# %%
ng_epta_ppta_snr_orfnotset=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_notone.npy")
#ng_snr=np.load("/Users/physics/nanogw/SNR_mar_data/ng_snr.npy")
ng_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_snr_vg.npy")
#epta_snr=np.load("/Users/physics/nanogw/SNR_mar_data/epta_snr.npy")
epta_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/epta_snr_vg.npy")
ppta_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/ppta_snr_vg.npy")

# %%
plt.hist(ng_epta_ppta_snr_orfnotset, histtype='step', lw=2, label='Combined 3 PTAs', color='C0',
         bins=20, density=True)
#plt.hist(ng_snr, histtype='step', lw=2, label='NANOGrav', color='C1',
         #bins=20, density=True)
plt.hist(ng_mar_snr, histtype='step', lw=2, label='NANOGrav Restricted NMOS', color='C2',
         bins=20, density=True)
#plt.hist(epta_snr, histtype='step', lw=2, label='EPTA', color='C3',
         #bins=20, density=True)
plt.hist(epta_mar_snr, histtype='step', lw=2, label='EPTA Restricted NMOS', color='C4',
         bins=20, density=True)
plt.hist(ppta_mar_snr, histtype='step', lw=2, label='PPTA Restricted NMOS', color='C5',
         bins=20, density=True)

plt.gca().axvline(x=np.mean(ng_epta_ppta_snr_orfnotset), ls='--', color='C0')
#plt.gca().axvline(x=np.mean(ng_snr), ls='--', color='C1')
plt.gca().axvline(x=np.mean(ng_mar_snr), ls='--', color='C2')
#plt.gca().axvline(x=np.mean(epta_snr), ls='--', color='C3')
plt.gca().axvline(x=np.mean(epta_mar_snr), ls='--', color='C4')
plt.gca().axvline(x=np.mean(ppta_mar_snr), ls='--', color='C5')

plt.title("ORF Not Set For Same Pulsars")
plt.legend(loc="upper right")
plt.xlabel("S/N")
plt.ylabel("PDF")
plt.savefig("EPTA_NANOGrav.pdf")

# %%
ng_epta_ppta_snr_orfone=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_one.npy")
ng_snr_ptaspace=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_pta_space_mar_snr.npy")
epta_snr_ptaspace=np.load("/Users/kalistaw/Desktop/OS_2023_data/epta_pta_space_mar_snr.npy")
ppta_snr_ptaspace=np.load("/Users/kalistaw/Desktop/OS_2023_data/ppta_pta_space_mar_snr.npy")

# %%
plt.hist(ng_epta_ppta_snr_orfone, histtype='step', lw=2, label='Combined 3 PTAs', color='C0',
         bins=20, density=True)
plt.hist(ng_mar_snr, histtype='step', lw=2, label='NANOGrav Restricted NMOS', color='C2',
         bins=20, density=True)
plt.hist(epta_mar_snr, histtype='step', lw=2, label='EPTA Restricted NMOS', color='C4',
         bins=20, density=True)
plt.hist(ppta_mar_snr, histtype='step', lw=2, label='PPTA Restricted NMOS', color='C1',
         bins=20, density=True)

plt.hist(ng_snr_ptaspace, histtype='step', ls='--', label='NANOGrav NMOS', color='C2',
         bins=20, density=True)
plt.hist(epta_snr_ptaspace, histtype='step', ls='--', label='EPTA NMOS', color='C4',
         bins=20, density=True)
plt.hist(ppta_snr_ptaspace, histtype='step', ls='--', label='PPTA NMOS', color='C1',
         bins=20, density=True)

plt.gca().axvline(x=np.mean(ng_epta_ppta_snr_orfone), ls='--', color='C0')
plt.gca().axvline(x=np.mean(ng_mar_snr), lw=1, color='C2')
plt.gca().axvline(x=np.mean(epta_mar_snr), lw=1, color='C4')
plt.gca().axvline(x=np.mean(ppta_mar_snr), lw=1, color='C1')

plt.gca().axvline(x=np.mean(ng_snr_ptaspace), ls='--', color='C2')
plt.gca().axvline(x=np.mean(epta_snr_ptaspace), ls='--', color='C4')
plt.gca().axvline(x=np.mean(ppta_snr_ptaspace), ls='--', color='C1')

plt.title("ORF Set to One For Same Pulsars")
plt.legend(loc="upper right")
plt.xlabel("S/N")
plt.ylabel("PDF")
plt.savefig("EPTA_NANOGrav.pdf")

# %%
plt.hist(ng_epta_ppta_snr_orfzero, histtype='step', lw=2, label='Combined 3 PTAs', color='C0',
         bins=20, density=True)
plt.hist(ng_mar_snr, histtype='step', lw=2, label='NANOGrav Restricted NMOS', color='C2',
         bins=20, density=True)
plt.hist(epta_mar_snr, histtype='step', lw=2, label='EPTA Restricted NMOS', color='C4',
         bins=20, density=True)
plt.hist(ppta_mar_snr, histtype='step', lw=2, label='PPTA Restricted NMOS', color='C5',
         bins=20, density=True)

plt.gca().axvline(x=np.mean(ng_epta_ppta_snr_orfone), ls='--', color='C0')
plt.gca().axvline(x=np.mean(ng_mar_snr), ls='--', color='C2')
plt.gca().axvline(x=np.mean(epta_mar_snr), ls='--', color='C4')
plt.gca().axvline(x=np.mean(ppta_mar_snr), ls='--', color='C5')

plt.title("ORF Set to Zero For Same Pulsars")
plt.legend(loc="upper right")
plt.xlabel("S/N")
plt.ylabel("PDF")
plt.savefig("EPTA_NANOGrav.pdf")

# %%
np.mean(ng_epta_ppta_snr_orfone)
# Out:
# 1.303801738015438

# %%
np.mean(ng_epta_ppta_snr_orfnotset)
# Out:
# 1.9316629449344118

# %%
np.mean(ng_epta_ppta_snr_orfzero)
# Out:
# 6.882093377651386

# %%
ppta_freq=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_fx_gamma.npy")
epta_freq=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_epta_fx_gamma.npy")
ng_freq=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ng_fx_gamma.npy")

# %%
plt.hist(ppta_freq, histtype='step', lw=2, label='NMOS with PPTA Frequencies', color='k',
         bins=20, density=True)
plt.hist(epta_freq, histtype='step', lw=2, label='NMOS with EPTA Frequencies', color='dimgray',
         bins=20, density=True)
plt.hist(ng_freq, histtype='step', lw=2, label='NMOS with NG Frequencies', color='darkgrey',
         bins=20, density=True)

plt.gca().axvline(x=np.mean(ppta_freq), lw=2, color='k')
plt.gca().axvline(x=np.mean(epta_freq), lw=2, color='dimgray')
plt.gca().axvline(x=np.mean(ng_freq), lw=2, color='darkgrey')


plt.legend(loc="upper right")
plt.title("Combined NMOS Over Different PTA Frequencies")
plt.xlabel("S/N")
plt.ylabel("PDF")
#plt.savefig("/Users/kalistaw/Desktop/freq_snr_comp_plot.pdf")
# Out:
# Text(0, 0.5, 'PDF')

# %%
np.mean(ppta_freq)
# Out:
# 7.969221395731627

# %%
np.mean(ppta_freq)
# Out:
# 7.969221395731627

# %%
np.mean(ng_freq)
# Out:
# 7.4214580711044364

# %%
ng_epta_ng_freq=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ng_fx_gamma_2_ng_epta.npy")
ng_epta_epta_freq=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_epta_fx_gamma_2_ng_epta.npy")
ng_epta_ppta_freq=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_fx_gamma_2_ng_epta.npy")

# %%
plt.hist(ng_epta_ppta_freq, histtype='step', lw=2, label='NMOS with PPTA Frequencies', color='k',
         bins=20, density=True)
plt.hist(ng_epta_epta_freq, histtype='step', lw=2, label='NMOS with EPTA Frequencies', color='dimgray',
         bins=20, density=True)
plt.hist(ng_epta_ng_freq, histtype='step', lw=2, label='NMOS with NG Frequencies', color='darkgrey',
         bins=20, density=True)


plt.gca().axvline(x=np.mean(ng_epta_epta_freq), lw=2, color='dimgray')
plt.gca().axvline(x=np.mean(ng_epta_ng_freq), lw=2, color='darkgrey')
plt.gca().axvline(x=np.mean(ng_epta_ppta_freq), lw=2, color='k')

plt.legend(loc="upper right")
plt.title("Combined NMOS of Only NG EPTA Over Different PTA Frequencies")
plt.xlabel("S/N")
plt.ylabel("PDF")
# Out:
# Text(0, 0.5, 'PDF')

# %%
np.mean(ng_epta_ng_freq)
# Out:
# 8.553213380681035

# %%
np.mean(ng_epta_ppta_freq)
# Out:
# 8.52789867036354

# %%
ppta_ng=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_fx_gamma_2_ppta_ng.npy")
ppta_epta=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_fx_gamma_2_ppta_epta.npy")
ng_epta=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_fx_gamma_2_ng_epta.npy")
combined=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_fx_gamma.npy")

# %%
plt.hist(combined, histtype='step', lw=2, label='Combined 3 PTAs', color='k',
         bins=20, density=True)
plt.hist(ppta_ng, histtype='step', lw=2, label='PPTA_NG', color='C2',
         bins=20, density=True)
plt.hist(ppta_epta, histtype='step', lw=2, label='PPTA_EPTA', color='C3',
         bins=20, density=True)
plt.hist(ng_epta, histtype='step', lw=2, label='NG_EPTA', color='C0',
         bins=20, density=True)

plt.gca().axvline(x=np.mean(combined), lw=2, color='k')
plt.gca().axvline(x=np.mean(ppta_ng), lw=1, color='C2')
plt.gca().axvline(x=np.mean(ppta_epta), lw=1, color='C3')
plt.gca().axvline(x=np.mean(ng_epta), lw=1, color='C0')

plt.legend(loc="upper right")
plt.title("Combined NMOS Over Different PTA Combinations Fx Gamma")
plt.xlabel("S/N")
plt.ylabel("PDF")
# Out:
# Text(0, 0.5, 'PDF')

# %%
np.mean(combined)
# Out:
# 7.969221395731627

# %%
np.mean(ng_epta)
# Out:
# 8.52789867036354

# %%
combined=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_unq_idx.npy")
ppta_ng=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_var_gamma_2_ppta_ng.npy")
ppta_epta=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_var_gamma_2_ppta_epta.npy")
ng_epta=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_var_gamma_2_ng_epta.npy")

# %%
plt.hist(combined, histtype='step', lw=2, label='Combined 3 PTAs', color='k',
         bins=20, density=True)
plt.hist(ppta_ng, histtype='step', lw=2, label='PPTA_NG', color='C2',
         bins=20, density=True)
plt.hist(ppta_epta, histtype='step', lw=2, label='PPTA_EPTA', color='C3',
         bins=20, density=True)
plt.hist(ng_epta, histtype='step', lw=2, label='NG_EPTA', color='C0',
         bins=20, density=True)

plt.gca().axvline(x=np.mean(combined), lw=2, color='k')
plt.gca().axvline(x=np.mean(ppta_ng), lw=1, color='C2')
plt.gca().axvline(x=np.mean(ppta_epta), lw=1, color='C3')
plt.gca().axvline(x=np.mean(ng_epta), lw=1, color='C0')

plt.legend(loc="upper right")
plt.title("Combined NMOS Over Different PTA Combinations Var Gamma")
plt.xlabel("S/N")
plt.ylabel("PDF")
# Out:
# Text(0, 0.5, 'PDF')

# %%
np.mean(combined)
# Out:
# 7.437510197325169

# %%
np.mean(ng_epta)
# Out:
# 7.957876204739878

# %%
ng_epta_ppta_snr_orfzero=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_unq_idx.npy")
ng_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_snr_vg_tspan_ppta_unq_idx.npy")
epta_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/epta_snr_vg_tspan_ppta_unq_idx.npy")
ppta_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/ppta_snr_vg_tspan_ppta_unq_idx.npy")

# %%
plt.hist(ng_epta_ppta_snr_orfzero, histtype='step', lw=2, label='Combined 3 PTAs', color='k',
         bins=20, density=True)
plt.hist(ng_mar_snr, histtype='step', lw=2, label='NANOGrav 3P+ NMOS', color='C2',
         bins=20, density=True)
plt.hist(epta_mar_snr, histtype='step', lw=2, label='EPTA 3P+ NMOS', color='C3',
         bins=20, density=True)
plt.hist(ppta_mar_snr, histtype='step', lw=2, label='PPTA 3P+ NMOS', color='C0',
         bins=20, density=True)

plt.hist(ng_snr_ptaspace, histtype='step', ls='--', label='NANOGrav NMOS', color='C2',
         bins=20, density=True)
plt.hist(epta_snr_ptaspace, histtype='step', ls='--', label='EPTA NMOS', color='C3',
         bins=20, density=True)
plt.hist(ppta_snr_ptaspace, histtype='step', ls='--', label='PPTA NMOS', color='C0',
         bins=20, density=True)

plt.gca().axvline(x=np.mean(ng_epta_ppta_snr_orfzero), lw=2, color='k')
plt.gca().axvline(x=np.mean(ng_mar_snr), lw=1, color='C2')
plt.gca().axvline(x=np.mean(epta_mar_snr), lw=1, color='C3')
plt.gca().axvline(x=np.mean(ppta_mar_snr), lw=1, color='C0')

plt.gca().axvline(x=np.mean(ng_snr_ptaspace), ls='--', color='C2')
plt.gca().axvline(x=np.mean(epta_snr_ptaspace), ls='--', color='C3')
plt.gca().axvline(x=np.mean(ppta_snr_ptaspace), ls='--', color='C0')

plt.legend(loc="upper right")
plt.title("NMOS with Full Timespan Frequencies Across PTAs")
plt.xlabel("S/N")
plt.ylabel("PDF")
plt.savefig("/Users/kalistaw/Desktop/OS_Plots/fx_gamma_snr_set_dmgp.pdf")

# %%
np.mean(ng_epta_ppta_snr_orfzero)
# Out:
# 7.437510197325169

# %%
ng_epta_ppta_snr_orfzero=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_epta_ppta_snr_orf_zero_vg_tspan_ppta_fx_gamma.npy")
ng_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/ng_snr_vg_tspan_ppta_fx_gamma.npy")
epta_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/epta_snr_vg_tspan_ppta_fx_gamma.npy")
ppta_mar_snr=np.load("/Users/kalistaw/Desktop/OS_2023_data/ppta_snr_vg_tspan_ppta_")

# %%
plt.hist(ng_epta_ppta_snr_orfzero, histtype='step', lw=2, label='Combined 3 PTAs', color='k',
         bins=20, density=True)
plt.hist(ng_mar_snr, histtype='step', lw=2, label='NANOGrav 3P+ NMOS', color='C2',
         bins=20, density=True)
plt.hist(epta_mar_snr, histtype='step', lw=2, label='EPTA 3P+ NMOS', color='C3',
         bins=20, density=True)
plt.hist(ppta_mar_snr, histtype='step', lw=2, label='PPTA 3P+ NMOS', color='C0',
         bins=20, density=True)

plt.hist(ng_snr_ptaspace, histtype='step', ls='--', label='NANOGrav NMOS', color='C2',
         bins=20, density=True)
plt.hist(epta_snr_ptaspace, histtype='step', ls='--', label='EPTA NMOS', color='C3',
         bins=20, density=True)
plt.hist(ppta_snr_ptaspace, histtype='step', ls='--', label='PPTA NMOS', color='C0',
         bins=20, density=True)

plt.gca().axvline(x=np.mean(ng_epta_ppta_snr_orfzero), lw=2, color='k')
plt.gca().axvline(x=np.mean(ng_mar_snr), lw=1, color='C2')
plt.gca().axvline(x=np.mean(epta_mar_snr), lw=1, color='C3')
plt.gca().axvline(x=np.mean(ppta_mar_snr), lw=1, color='C0')

plt.gca().axvline(x=np.mean(ng_snr_ptaspace), ls='--', color='C2')
plt.gca().axvline(x=np.mean(epta_snr_ptaspace), ls='--', color='C3')
plt.gca().axvline(x=np.mean(ppta_snr_ptaspace), ls='--', color='C0')

plt.legend(loc="upper right")
plt.title("NMOS with Full Timespan Frequencies Across PTAs")
plt.xlabel("S/N")
plt.ylabel("PDF")
plt.savefig("/Users/kalistaw/Desktop/OS_Plots/fx_gamma_snr_set_dmgp.pdf")

# %%
np.mean(ng_epta_ppta_snr_orfzero)
# Out:
# 7.969221395731627
